# %%
# Update sklearn to prevent version mismatches
# !pip install sklearn --upgrade
# Out:
# ...
#   Created wheel for sklearn: filename=sklearn-0.0-py2.py3-none-any.whl size=1316 sha256=d05da3dc60bc72c9ce8423f18ee3662d9919e80269fa80902a0cd3d8d53e09aa
#   Stored in directory: /Users/Andrew/Library/Caches/pip/wheels/22/0b/40/fd3f795caaa1fb4c6cb738bc1f56100be1e57da95849bfc897
# Successfully built sklearn
# ...

# %%
# install joblib. This will be used to save your model. 
# Restart your kernel after installing 
# !pip install joblib

# %%
import pandas as pd

# %% [markdown]
# # Read the CSV and Perform Basic Data Cleaning

# %%
df = pd.read_csv("exoplanet_data.csv")
# Drop the null columns where all values are null
df = df.dropna(axis='columns', how='all')
# Drop the null rows
df = df.dropna()
df.head()
# Out:
#   koi_disposition  koi_fpflag_nt  koi_fpflag_ss  koi_fpflag_co  koi_fpflag_ec  \
# 0       CONFIRMED              0              0              0              0
# 1  FALSE POSITIVE              0              1              0              0
# 2  FALSE POSITIVE              0              1              0              0
# 3       CONFIRMED              0              0              0              0
# 4       CONFIRMED              0              0              0              0
#
#    koi_period  koi_period_err1  koi_period_err2  koi_time0bk  \
# 0   54.418383     2.479000e-04    -2.479000e-04   162.513840
# 1   19.899140     1.490000e-05    -1.490000e-05   175.850252
# 2    1.736952     2.630000e-07    -2.630000e-07   170.307565
# 3    2.525592     3.760000e-06    -3.760000e-06   171.595550
# 4    4.134435     1.050000e-05    -1.050000e-05   172.979370
#
#    koi_time0bk_err1  ...  koi_steff_err2  koi_slogg  koi_slogg_err1  \
# ...

# %% [markdown]
# # Create a Train Test Split
#
# Use `koi_disposition` for the y values

# %%
X = df.drop('koi_disposition',axis=1) # use all features
y = df.loc[:,'koi_disposition']

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=1) # split

# %%
X_train.head()
# Out:
#       koi_fpflag_nt  koi_fpflag_ss  koi_fpflag_co  koi_fpflag_ec  koi_period  \
# 3563              0              0              0              0   10.548413
# 4099              0              0              0              0   24.754385
# 5460              0              0              0              0    1.057336
# 1091              0              0              0              0  201.118319
# 5999              0              0              0              0   91.649983
#
#       koi_period_err1  koi_period_err2  koi_time0bk  koi_time0bk_err1  \
# 3563     5.470000e-05    -5.470000e-05   139.064020          0.004110
# 4099     1.365000e-04    -1.365000e-04   140.207320          0.004460
# 5460     1.230000e-07    -1.230000e-07   131.792007          0.000096
# 1091     1.461000e-03    -1.461000e-03   187.569860          0.005290
# 5999     3.181000e-03    -3.181000e-03   175.715600          0.028600
#
#       koi_time0bk_err2  ...  koi_steff_err2  koi_slogg  koi_slogg_err1  \
# ...

# %%
y_train.head()
# Out:
# 3563    CANDIDATE
# 4099    CONFIRMED
# 5460    CANDIDATE
# 1091    CONFIRMED
# 5999    CANDIDATE
# Name: koi_disposition, dtype: object

# %% [markdown]
# # Pre-processing
#
# Scale the data using the MinMaxScaler and perform some feature selection

# %%
# Import Scaler and train it
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
scaler.fit(X_train)
# Out:
# MinMaxScaler()

# %%
# Create scaled test and train
X_train_scaled = scaler.transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %% [markdown]
# # Run a random forest to determine feature importance

# %%
# Create a random forest classifier and score
from sklearn.ensemble import RandomForestClassifier
rf = RandomForestClassifier(n_estimators=200)
rf = rf.fit(X_train_scaled, y_train)
rf.score(X_test_scaled, y_test)

# %%
# Determine Importances
importances = rf.feature_importances_
importance_df = pd.DataFrame(sorted(zip(rf.feature_importances_, X.columns), reverse=True))
importance_df
# Out:
#            0                  1
# 0   0.107377      koi_fpflag_co
# 1   0.096194      koi_fpflag_nt
# 2   0.067372      koi_fpflag_ss
# 3   0.054523      koi_model_snr
# 4   0.049234           koi_prad
# 5   0.037165      koi_fpflag_ec
# 6   0.035924  koi_duration_err1
# 7   0.033818      koi_prad_err2
# 8   0.032746  koi_duration_err2
# 9   0.030580     koi_steff_err1
# 10  0.029992      koi_prad_err1
# 11  0.024405     koi_steff_err2
# 12  0.024010   koi_time0bk_err2
# 13  0.023980       koi_duration
# 14  0.022352   koi_time0bk_err1
# 15  0.022031          koi_depth
# 16  0.021335         koi_period
# 17  0.019413     koi_insol_err1
# 18  0.019207            koi_teq
# 19  0.017629    koi_period_err2
# 20  0.017512    koi_period_err1
# 21  0.017381         koi_impact
# 22  0.014421     koi_depth_err2
# 23  0.014268        koi_time0bk
# 24  0.012991     koi_depth_err1
# 25  0.012930      koi_srad_err1
# 26  0.012446                 ra
# 27  0.012276     koi_insol_err2
# ...

# %% [markdown]
# The Fields I'd like to use are:
#
# ### Trial 1
# I'd like to use the Top 5 entries
# koi_fpflag_co, koi_fpflag_nt, koi_fpflag_ss, koi_model_snr, koi_prad
# Result: Terrible, I had like 52% accuracy and 1+ loss
#
# ### Trial 2
# Now let's try all fields
# Result: Loss: 0.26, Accuracy: 0.88 (Better)
